# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/mnt/c/Users/bilal/Downloads/model_performance.csv")

# %%
df
# Out:
#       model  accuracy  precision  recall  f1score  cohenkappa_score  \
# 0  ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# 1       adb    0.7265     0.7539  0.7468   0.7495            0.4421
# 2        rf    0.7807     0.8044  0.7922   0.7961            0.5368
# 3       knn    0.6610     0.6945  0.6883   0.6910            0.3161
# 4        ng    0.7550     0.7762  0.7727   0.7741            0.5032
# 5        lr    0.7612     0.7933  0.7727   0.7791            0.4874
#
#    matthews_corrcoef
# 0             0.5425
# 1             0.4433
# 2             0.5405
# 3             0.3166
# 4             0.5037
# 5             0.4938

# %%
df.set_index("model", inplace=True)

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# ng                   0.5037
# lr                   0.4938

# %%
df.max(axis=1)
# Out:
# model
# ensemble    0.8003
# adb         0.7539
# rf          0.8044
# knn         0.6945
# ng          0.7762
# lr          0.7933
# dtype: float64

# %%
df.max(axis=0)
# Out:
# accuracy             0.7807
# precision            0.8044
# recall               0.7922
# f1score              0.7961
# cohenkappa_score     0.5405
# matthews_corrcoef    0.5425
# dtype: float64

# %%
df.min(axis=0)
# Out:
# accuracy             0.6610
# precision            0.6945
# recall               0.6883
# f1score              0.6910
# cohenkappa_score     0.3161
# matthews_corrcoef    0.3166
# dtype: float64

# %%
df.min(axis=1)
# Out:
# model
# ensemble    0.5405
# adb         0.4421
# rf          0.5368
# knn         0.3161
# ng          0.5032
# lr          0.4874
# dtype: float64

# %%
error= [0.2,0.67,0.9,0.32,0.12,0.21]

df["error"]=error

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425   0.20
# adb                  0.4433   0.67
# rf                   0.5405   0.90
# knn                  0.3166   0.32
# ng                   0.5037   0.12
# lr                   0.4938   0.21

# %%
fg =[1,3,6.7,0.2,9.0,5.2,1.2]
df.loc["fg"]=fg

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# ng          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# fg          1.0000     3.0000  6.7000   0.2000            9.0000
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425   0.20
# adb                  0.4433   0.67
# rf                   0.5405   0.90
# knn                  0.3166   0.32
# ng                   0.5037   0.12
# lr                   0.4938   0.21
# fg                   5.2000   1.20

# %%
nb ={"ng":"nb"}

df.rename(nb, axis=0, inplace=True)

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# fg          1.0000     3.0000  6.7000   0.2000            9.0000
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425   0.20
# adb                  0.4433   0.67
# rf                   0.5405   0.90
# knn                  0.3166   0.32
# nb                   0.5037   0.12
# lr                   0.4938   0.21
# fg                   5.2000   1.20

# %%
df.drop(["error"], axis=1)
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# fg          1.0000     3.0000  6.7000   0.2000            9.0000
#
#           matthews_corrcoef
# model
# ensemble             0.5425
# adb                  0.4433
# rf                   0.5405
# knn                  0.3166
# nb                   0.5037
# lr                   0.4938
# fg                   5.2000

# %%
df_2=df.drop(["fg"], axis=0)

# %%
df_2
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425   0.20
# adb                  0.4433   0.67
# rf                   0.5405   0.90
# knn                  0.3166   0.32
# nb                   0.5037   0.12
# lr                   0.4938   0.21

# %%
df_2[(df_2["accuracy"]>0.77)]
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425    0.2
# rf                   0.5405    0.9

# %%
df_2["accuracy"]>0.77
# Out:
# model
# ensemble     True
# adb         False
# rf           True
# knn         False
# nb          False
# lr          False
# Name: accuracy, dtype: bool

# %%
df_long = df_2.reset_index().melt(
    id_vars="model",                            #set index (model) to a column, not index
    value_vars=["precision", "accuracy"], 
    var_name="metric", 
    value_name="score"
)

print(df_long)
# Out:
#        model     metric   score
# 0   ensemble  precision  0.8003
# 1        adb  precision  0.7539
# 2         rf  precision  0.8044
# 3        knn  precision  0.6945
# 4         nb  precision  0.7762
# 5         lr  precision  0.7933
# 6   ensemble   accuracy  0.7787
# 7        adb   accuracy  0.7265
# 8         rf   accuracy  0.7807
# 9        knn   accuracy  0.6610
# 10        nb   accuracy  0.7550
# 11        lr   accuracy  0.7612

# %%
plt.figure(figsize=(8,6))
sns.barplot(x="model", y="score", hue="metric", data=df_long)
plt.title("Model Performance", fontweight="bold", fontsize=15)
plt.xlabel("Model", rotation=45, ha="right", fontsize=12)
plt.ylabel("Score", fontsize=12)


sns.despine()

plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
# fg          1.0000     3.0000  6.7000   0.2000            9.0000
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425   0.20
# adb                  0.4433   0.67
# rf                   0.5405   0.90
# knn                  0.3166   0.32
# nb                   0.5037   0.12
# lr                   0.4938   0.21
# fg                   5.2000   1.20

# %%
df_long
# Out:
#        model     metric   score
# 0   ensemble  precision  0.8003
# 1        adb  precision  0.7539
# 2         rf  precision  0.8044
# 3        knn  precision  0.6945
# 4         nb  precision  0.7762
# 5         lr  precision  0.7933
# 6   ensemble   accuracy  0.7787
# 7        adb   accuracy  0.7265
# 8         rf   accuracy  0.7807
# 9        knn   accuracy  0.6610
# 10        nb   accuracy  0.7550
# 11        lr   accuracy  0.7612

# %%
df_2
# Out:
#           accuracy  precision  recall  f1score  cohenkappa_score  \
# model
# ensemble    0.7787     0.8003  0.7922   0.7950            0.5405
# adb         0.7265     0.7539  0.7468   0.7495            0.4421
# rf          0.7807     0.8044  0.7922   0.7961            0.5368
# knn         0.6610     0.6945  0.6883   0.6910            0.3161
# nb          0.7550     0.7762  0.7727   0.7741            0.5032
# lr          0.7612     0.7933  0.7727   0.7791            0.4874
#
#           matthews_corrcoef  error
# model
# ensemble             0.5425   0.20
# adb                  0.4433   0.67
# rf                   0.5405   0.90
# knn                  0.3166   0.32
# nb                   0.5037   0.12
# lr                   0.4938   0.21

# %%
import pandas as pd

# %%
pd.read_csv("/mnt/c/Users/bilal/Downloads/deseq_deg.tsv", delimiter="\t")
# Out:
#           GeneName      padj    pvalue     lfcSE       stat  log2FoldChange  \
# 0             ELF3  0.000000  0.000000  0.048405 -39.071769       -1.891272
# 1              LBH  0.000000  0.000000  0.044448  41.784157        1.857243
# 2          MARCHF4  0.000000  0.000000  0.069079  46.656022        3.222939
# 3             TNS1  0.000000  0.000000  0.069233  46.688124        3.232365
# 4            F2RL1  0.000000  0.000000  0.042387  46.138132        1.955635
# ...            ...       ...       ...       ...        ...             ...
# 1486         KCNJ8  0.048712  0.020112  0.507700  -2.324251       -1.180023
# 1487  LOC105370091  0.048753  0.020134  0.658347   2.323836        1.529890
# 1488      AFTPH-DT  0.049395  0.020467  0.630896  -2.317678       -1.462214
# 1489          LYG2  0.049617  0.020578  0.751578  -2.315644       -1.740386
# 1490        TMEM52  0.049650  0.020597  0.491839  -2.315296       -1.138752
#
#           baseMean
# 0      4685.370552
# ...

# %%
df3=pd.read_csv("/mnt/c/Users/bilal/Downloads/deseq_deg.tsv", delimiter="\t")

# %%
df3
# Out:
#           GeneName      padj    pvalue     lfcSE       stat  log2FoldChange  \
# 0             ELF3  0.000000  0.000000  0.048405 -39.071769       -1.891272
# 1              LBH  0.000000  0.000000  0.044448  41.784157        1.857243
# 2          MARCHF4  0.000000  0.000000  0.069079  46.656022        3.222939
# 3             TNS1  0.000000  0.000000  0.069233  46.688124        3.232365
# 4            F2RL1  0.000000  0.000000  0.042387  46.138132        1.955635
# ...            ...       ...       ...       ...        ...             ...
# 1486         KCNJ8  0.048712  0.020112  0.507700  -2.324251       -1.180023
# 1487  LOC105370091  0.048753  0.020134  0.658347   2.323836        1.529890
# 1488      AFTPH-DT  0.049395  0.020467  0.630896  -2.317678       -1.462214
# 1489          LYG2  0.049617  0.020578  0.751578  -2.315644       -1.740386
# 1490        TMEM52  0.049650  0.020597  0.491839  -2.315296       -1.138752
#
#           baseMean
# 0      4685.370552
# ...

# %%
df3.shape
# Out:
# (1491, 7)

# %%
df3.describe
# Out:
# <bound method NDFrame.describe of           GeneName      padj    pvalue     lfcSE       stat  log2FoldChange  \
# 0             ELF3  0.000000  0.000000  0.048405 -39.071769       -1.891272
# 1              LBH  0.000000  0.000000  0.044448  41.784157        1.857243
# 2          MARCHF4  0.000000  0.000000  0.069079  46.656022        3.222939
# 3             TNS1  0.000000  0.000000  0.069233  46.688124        3.232365
# 4            F2RL1  0.000000  0.000000  0.042387  46.138132        1.955635
# ...            ...       ...       ...       ...        ...             ...
# 1486         KCNJ8  0.048712  0.020112  0.507700  -2.324251       -1.180023
# 1487  LOC105370091  0.048753  0.020134  0.658347   2.323836        1.529890
# 1488      AFTPH-DT  0.049395  0.020467  0.630896  -2.317678       -1.462214
# 1489          LYG2  0.049617  0.020578  0.751578  -2.315644       -1.740386
# 1490        TMEM52  0.049650  0.020597  0.491839  -2.315296       -1.138752
#
#           baseMean
# ...

# %%
df3[(df3["lfcSE"]>0.2) & (df3["log2FoldChange"]<2)]
# Out:
#           GeneName          padj        pvalue     lfcSE       stat  \
# 199       C9orf152  3.289764e-90  3.736531e-92  0.204083 -20.360642
# 466          KRT20  2.966036e-30  1.172615e-31  0.280826 -11.707070
# 495          VTCN1  1.490530e-27  6.446237e-29  0.204513 -11.159348
# 500         CX3CL1  2.850880e-27  1.251629e-28  0.244292 -11.100200
# 520          SOX21  9.477432e-26  4.424837e-27  0.253137 -10.776914
# ...            ...           ...           ...       ...        ...
# 1486         KCNJ8  4.871201e-02  2.011203e-02  0.507700  -2.324251
# 1487  LOC105370091  4.875306e-02  2.013430e-02  0.658347   2.323836
# 1488      AFTPH-DT  4.939494e-02  2.046682e-02  0.630896  -2.317678
# 1489          LYG2  4.961687e-02  2.057774e-02  0.751578  -2.315644
# 1490        TMEM52  4.964957e-02  2.059672e-02  0.491839  -2.315296
#
#       log2FoldChange    baseMean
# 199        -4.155263  251.500647
# 466        -3.287648   87.403431
# 495        -2.282234  130.080642
# ...

# %%
df3_long1=df3.melt(id_vars="GeneName",
                  value_vars=["log2FoldChange","baseMean"],
                  var_name="metric",
                  value_name="score"
                 )


print(df3_long1)
# Out:
#           GeneName          metric      score
# 0             ELF3  log2FoldChange  -1.891272
# 1              LBH  log2FoldChange   1.857243
# 2          MARCHF4  log2FoldChange   3.222939
# 3             TNS1  log2FoldChange   3.232365
# 4            F2RL1  log2FoldChange   1.955635
# ...            ...             ...        ...
# 2977         KCNJ8        baseMean  14.911313
# 2978  LOC105370091        baseMean   9.576288
# 2979      AFTPH-DT        baseMean  11.395338
# 2980          LYG2        baseMean   8.109186
# 2981        TMEM52        baseMean  16.239947
#
# [2982 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))

sns.barplot(x="GeneName", y="score", hue="metric", data=df3_long1)
plt.title ("Gene Expession", fontweight="bold",fontsize=15)
plt.xlabel("Gene_Name", rotation=45, ha="right")
plt.ylabel("Score")

plt.legend()
    
sns.despine()
plt.tight_layout()
plt.show()

# %%
file=df3_long1.loc[:,:]

# %%
file
# Out:
#           GeneName          metric      score
# 0             ELF3  log2FoldChange  -1.891272
# 1              LBH  log2FoldChange   1.857243
# 2          MARCHF4  log2FoldChange   3.222939
# 3             TNS1  log2FoldChange   3.232365
# 4            F2RL1  log2FoldChange   1.955635
# ...            ...             ...        ...
# 2977         KCNJ8        baseMean  14.911313
# 2978  LOC105370091        baseMean   9.576288
# 2979      AFTPH-DT        baseMean  11.395338
# 2980          LYG2        baseMean   8.109186
# 2981        TMEM52        baseMean  16.239947
#
# [2982 rows x 3 columns]

# %%
file.to_csv("file_tsv", sep="\t", index=False)

# %%
df3
# Out:
#           GeneName      padj    pvalue     lfcSE       stat  log2FoldChange  \
# 0             ELF3  0.000000  0.000000  0.048405 -39.071769       -1.891272
# 1              LBH  0.000000  0.000000  0.044448  41.784157        1.857243
# 2          MARCHF4  0.000000  0.000000  0.069079  46.656022        3.222939
# 3             TNS1  0.000000  0.000000  0.069233  46.688124        3.232365
# 4            F2RL1  0.000000  0.000000  0.042387  46.138132        1.955635
# ...            ...       ...       ...       ...        ...             ...
# 1486         KCNJ8  0.048712  0.020112  0.507700  -2.324251       -1.180023
# 1487  LOC105370091  0.048753  0.020134  0.658347   2.323836        1.529890
# 1488      AFTPH-DT  0.049395  0.020467  0.630896  -2.317678       -1.462214
# 1489          LYG2  0.049617  0.020578  0.751578  -2.315644       -1.740386
# 1490        TMEM52  0.049650  0.020597  0.491839  -2.315296       -1.138752
#
#           baseMean
# 0      4685.370552
# ...

# %%
df3.rename({"pvalue":"p_value"}, axis=1)
# Out:
#           GeneName      padj   p_value     lfcSE       stat  log2FoldChange  \
# 0             ELF3  0.000000  0.000000  0.048405 -39.071769       -1.891272
# 1              LBH  0.000000  0.000000  0.044448  41.784157        1.857243
# 2          MARCHF4  0.000000  0.000000  0.069079  46.656022        3.222939
# 3             TNS1  0.000000  0.000000  0.069233  46.688124        3.232365
# 4            F2RL1  0.000000  0.000000  0.042387  46.138132        1.955635
# ...            ...       ...       ...       ...        ...             ...
# 1486         KCNJ8  0.048712  0.020112  0.507700  -2.324251       -1.180023
# 1487  LOC105370091  0.048753  0.020134  0.658347   2.323836        1.529890
# 1488      AFTPH-DT  0.049395  0.020467  0.630896  -2.317678       -1.462214
# 1489          LYG2  0.049617  0.020578  0.751578  -2.315644       -1.740386
# 1490        TMEM52  0.049650  0.020597  0.491839  -2.315296       -1.138752
#
#           baseMean
# 0      4685.370552
# ...

# %%
file_tsv= "/mnt/c/Users/bilal/Downloads/variants.vcf.gz"

# %%
file_tsv
# Out:
# '/mnt/c/Users/bilal/Downloads/variants.vcf.gz'

# %%
import pandas as pd

# %%
#reading the VCF file   but with comment="#" it will skip all lines with #character
df_variant= pd.read_csv(file_tsv, sep="\t", comment="#")

# %%
df_variant
# Out:
#         1     1157  .  T    C     166734  \
# 0       1     1196  .  A    T   696707.0
# 1       1     1414  .  C    T   324038.0
# 2       1     1435  .  T    C   495439.0
# 3       1     1450  .  A  T,C  2703220.0
# 4       1     3701  .  T    A   146932.0
# ...    ..      ... .. ..  ...        ...
# 26888  14  3282738  .  T    C    85321.5
# 26889  14  3283008  .  T    A   326363.0
# 26890  14  3283026  .  T    C    60189.9
# 26891  14  3283127  .  A    G    60840.1
# 26892  14  3283182  .  A    G   438544.0
#
#               Low_VQSLOD;SubtelomericRepeat  \
# 0             Low_VQSLOD;SubtelomericRepeat
# 1             Low_VQSLOD;SubtelomericRepeat
# 2             Low_VQSLOD;SubtelomericRepeat
# 3             Low_VQSLOD;SubtelomericRepeat
# 4             Low_VQSLOD;SubtelomericRepeat
# ...                                     ...
# 26888  Low_VQSLOD;SubtelomericHypervariable
# 26889  Low_VQSLOD;SubtelomericHypervariable
# 26890  Low_VQSLOD;SubtelomericHypervariable
# ...

# %%
df_variant.index
# Out:
# RangeIndex(start=0, stop=26893, step=1)

# %%
#This will list all the numbers (indexes) from 0 - 2982
list(df_variant.index)

# %%
#properly reading VCF file 
import os

# %%
#Getting headers
cmd= "zgrep '^#' " + file_tsv + "| tail -n 1"

# %%
columns=os.popen(cmd).read()

# %%
print(columns)
# Out:
# #CHROM	POS	ID	REF	ALT	QUAL	FILTER	INFO	FORMAT	PR0114-C	PR0115-C	PR0116-C	PR0117-C	PR0118-C	PR0119-C	PR0120-C	PR0121-C	PR0122-C	PR0123-C

# %%
columns=columns.strip("#")

# %%
columns
# Out:
# 'CHROM\tPOS\tID\tREF\tALT\tQUAL\tFILTER\tINFO\tFORMAT\tPR0114-C\tPR0115-C\tPR0116-C\tPR0117-C\tPR0118-C\tPR0119-C\tPR0120-C\tPR0121-C\tPR0122-C\tPR0123-C\n'

# %%
columns=columns.strip("\n")

# %%
columns
# Out:
# 'CHROM\tPOS\tID\tREF\tALT\tQUAL\tFILTER\tINFO\tFORMAT\tPR0114-C\tPR0115-C\tPR0116-C\tPR0117-C\tPR0118-C\tPR0119-C\tPR0120-C\tPR0121-C\tPR0122-C\tPR0123-C'

# %%
columns=columns.split("\t")

# %%
print(columns)
# Out:
# ['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT', 'PR0114-C', 'PR0115-C', 'PR0116-C', 'PR0117-C', 'PR0118-C', 'PR0119-C', 'PR0120-C', 'PR0121-C', 'PR0122-C', 'PR0123-C']

# %%
len(columns)
# Out:
# 19

# %%
file_tsv= "/mnt/c/Users/bilal/Downloads/variants.vcf.gz"

# %%
df_variant=pd.read_csv(file_tsv,sep='\t',comment='#',names=columns)

# %%
df_variant
# Out:
#        CHROM      POS ID REF  ALT       QUAL  \
# 0          1     1157  .   T    C   166734.0
# 1          1     1196  .   A    T   696707.0
# 2          1     1414  .   C    T   324038.0
# 3          1     1435  .   T    C   495439.0
# 4          1     1450  .   A  T,C  2703220.0
# ...      ...      ... ..  ..  ...        ...
# 26889     14  3282738  .   T    C    85321.5
# 26890     14  3283008  .   T    A   326363.0
# 26891     14  3283026  .   T    C    60189.9
# 26892     14  3283127  .   A    G    60840.1
# 26893     14  3283182  .   A    G   438544.0
#
#                                      FILTER  \
# 0             Low_VQSLOD;SubtelomericRepeat
# 1             Low_VQSLOD;SubtelomericRepeat
# 2             Low_VQSLOD;SubtelomericRepeat
# 3             Low_VQSLOD;SubtelomericRepeat
# 4             Low_VQSLOD;SubtelomericRepeat
# ...                                     ...
# 26889  Low_VQSLOD;SubtelomericHypervariable
# 26890  Low_VQSLOD;SubtelomericHypervariable
# ...

# %%
df_variant.shape
# Out:
# (26894, 19)

# %%
subsets=df_variant.head()

# %%
subsets
# Out:
#    CHROM   POS ID REF  ALT       QUAL                         FILTER  \
# 0      1  1157  .   T    C   166734.0  Low_VQSLOD;SubtelomericRepeat
# 1      1  1196  .   A    T   696707.0  Low_VQSLOD;SubtelomericRepeat
# 2      1  1414  .   C    T   324038.0  Low_VQSLOD;SubtelomericRepeat
# 3      1  1435  .   T    C   495439.0  Low_VQSLOD;SubtelomericRepeat
# 4      1  1450  .   A  T,C  2703220.0  Low_VQSLOD;SubtelomericRepeat
#
#                                                 INFO                  FORMAT  \
# 0  AC=0;AF=0.075;AN=18;BaseQRankSum=-3.266;Clippi...  GT:AD:DP:GQ:PGT:PID:PL
# 1  AC=3;AF=0.22;AN=20;BaseQRankSum=-0.592;Clippin...  GT:AD:DP:GQ:PGT:PID:PL
# 2  AC=2;AF=0.071;AN=20;BaseQRankSum=4.2;ClippingR...  GT:AD:DP:GQ:PGT:PID:PL
# 3  AC=1;AF=0.1;AN=20;BaseQRankSum=-4.336;Clipping...  GT:AD:DP:GQ:PGT:PID:PL
# 4  AC=7,1;AF=0.382,0.061;AN=20;BaseQRankSum=0.596...  GT:AD:DP:GQ:PGT:PID:PL
#
#                                             PR0114-C  \
# ...

# %%
subsets.columns
# Out:
# Index(['CHROM', 'POS', 'ID', 'REF', 'ALT', 'QUAL', 'FILTER', 'INFO', 'FORMAT',
#        'PR0114-C', 'PR0115-C', 'PR0116-C', 'PR0117-C', 'PR0118-C', 'PR0119-C',
#        'PR0120-C', 'PR0121-C', 'PR0122-C', 'PR0123-C'],
#       dtype='object')

# %%
subsets=df_variant.iloc[:,[0.1,3,4]]

# %%
subsets
# Out:
#        CHROM REF  ALT
# 0          1   T    C
# 1          1   A    T
# 2          1   C    T
# 3          1   T    C
# 4          1   A  T,C
# ...      ...  ..  ...
# 26889     14   T    C
# 26890     14   T    A
# 26891     14   T    C
# 26892     14   A    G
# 26893     14   A    G
#
# [26894 rows x 3 columns]

# %%
subsets.head()
# Out:
#    CHROM REF  ALT
# 0      1   T    C
# 1      1   A    T
# 2      1   C    T
# 3      1   T    C
# 4      1   A  T,C

# %%
subsets.to_csv("subsets.vcf", index=False)
